# %%
import sys
import os
sys.path.append(os.path.abspath('../src')) 
from data_loader import get_pitcher_id, get_pitching_data, save_data

# %%
player_id = get_pitcher_id('Gerrit', 'Cole')
print(player_id)
# Out:
# Gathering player lookup table. This may take a moment.
# 543037

# %%
df = get_pitching_data(player_id, "2024-03-28", "2024-10-01")
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Data Analysis Portfolio Projects/MLB Pitcher Analysis/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IDfg'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ...

# %%
from pybaseball import pitching_stats_range
p = pitching_stats_range("2024-03-28", "2024-10-01")
p
# Out:
#                      Name  Age  #days            Lev                   Tm   G  \
# 1           Andrew Abbott   25    279         Maj-NL           Cincinnati  25
# 2             Bryan Abreu   27    239         Maj-AL              Houston  78
# 3              Jason Adam   32    235  Maj-AL,Maj-NL  San Diego,Tampa Bay  75
# 4            Austin Adams   33    284         Maj-AL              Oakland  56
# 5               Ty Adcock   27    323         Maj-NL             New York   3
# ..                    ...  ...    ...            ...                  ...  ..
# 884        Ryan Zeferjahn   26    238         Maj-AL          Los Angeles  12
# 885           Angel Zerpa   24    237         Maj-AL          Kansas City  60
# 886           Tyler Zuber   29    300         Maj-AL            Tampa Bay   2
# 887        Yosver Zulueta   26    242         Maj-NL           Cincinnati  12
# 888  Guillo Zu\xc3\xb1iga   25    237         Maj-AL          Los Angeles  15
#
# ...
